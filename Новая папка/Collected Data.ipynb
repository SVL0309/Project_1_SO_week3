# %%
import pandas as pd
population_df = pd.read_csv(r"C:\Users\38095\Documents\GitHub\Project_1_SO_week3\population.csv")
average_income_df = pd.read_csv(r"C:\Users\38095\Documents\GitHub\Project_1_SO_week3\income_state.csv")

# %%
p_ai_df = pd.concat([population_df, average_income_df], axis=1)
p_ai_df
# Out:
#              State  Population                 State Av_income
# 0          Alabama   5,108,468               Alabama    50,920
# 1           Alaska     733,406                Alaska    68,664
# 2          Arizona   7,431,344               Arizona    58,390
# 3         Arkansas   3,067,732              Arkansas    52,604
# 4       California  38,965,193            California    77,013
# 5         Colorado   5,877,610              Colorado    75,708
# 6      Connecticut   3,617,176           Connecticut    83,340
# 7         Delaware   1,031,890              Delaware    63,177
# 8          Florida  22,610,726  District of Columbia    96,092
# 9          Georgia  11,029,227               Florida    64,804
# 10          Hawaii   1,435,138               Georgia    56,588
# 11           Idaho   1,964,726                Hawaii    61,813
# 12        Illinois  12,549,689                 Idaho    56,615
# 13         Indiana   6,862,199              Illinois    67,653
# ...
