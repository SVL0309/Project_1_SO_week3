# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\38095\Documents\GitHub\Project1-copies\postings.csv")
df
# Out:
#                                                job_title  \
# 0                              Data Analyst-SQL, Tableau
# 1                     Market Research & Insights Analyst
# 2                            Business Systems Analyst `1
# 3                    Senior VAT and Indirect Tax Analyst
# 4          Senior HRIS Analyst (Timekeeping and Payroll)
# ...                                                  ...
# 12889                        Business Operations Analyst
# 12890                            Senior Military Analyst
# 12891  Senior Military Systems Analyst to support the...
# 12892  Senior Military Analyst to support the Mission...
# 12893                    Senior Military Systems Analyst
#
#                                             company              job_location  \
# 0                                 Zortech Solutions         Mountain View, CA
# 1                     Indiana University Foundation           Bloomington, IN
# ...

# %%
df.nunique()
# Out:
# job_title          6797
# company            5283
# job_location       2446
# job_link          12894
# first_seen            1
# search_city         834
# search_country        4
# job level             2
# job_type              3
# job_summary       11163
# job_skills        12696
# dtype: int64

# %%
df.job_title.tolist()
# Out:
# ['Data Analyst-SQL, Tableau',
#  'Market Research & Insights Analyst',
#  'Business Systems Analyst `1',
#  'Senior VAT and Indirect Tax Analyst',
#  'Senior HRIS Analyst (Timekeeping and Payroll)',
#  'Business Intelligence Reporting Analyst 2',
#  'Business Analyst 2',
#  'Lead Business Analyst',
#  'Lead Senior Business Analyst',
#  'Business Analyst',
#  'GIS Analyst',
#  'Sr Business Systems Analyst',
#  'Senior Network Analyst - DDI',
#  'Sr Business Systems Analyst',
#  'Business Analyst III',
#  'Senior Network Analyst - Campus Network',
#  'Senior Finance Analyst – L&M Finance',
#  'Senior Accounting Analyst (Financial Reporting)',
#  'Senior VAT and Indirect Tax Analyst',
#  'Systems Analyst I, II, III, Senior',
#  'Store Operations Analyst',
#  'Senior Finance Analyst - L&M Finance',
#  'Senior Business & Legal Research Analyst',
#  'IT Business Analyst',
#  'Management Analyst III Agricultural Survey Statistician',
#  'Fiscal Management Analyst',
# ...

# %%
df["job_title"].value_counts()
# Out:
# job_title
# Business Analyst                            438
# Data Analyst                                332
# Senior Financial Analyst                    278
# Senior Data Analyst                         235
# Business Systems Analyst                    199
#                                            ...
# Senior Data Insights & Reporting Analyst      1
# Sales Business Analyst, Fragrance             1
# Data Analyst, Asset Management                1
# Position Management Analyst                   1
# Senior Military Systems Analyst               1
# Name: count, Length: 6797, dtype: int64

# %%
df1 = df[df['job_title'].str.contains('Data Analyst') & df['search_country'].str.contains('United States')]
df2 = df1[['job_title', 'job_location', 'first_seen', 'job_type']]
df2
# Out:
#                                                job_title  \
# 0                              Data Analyst-SQL, Tableau
# 31     Volunteer: Wildfire Prevention Financing Data ...
# 37     Volunteer: Biometric Data Analystat Nature Cou...
# 38     Volunteer: Medicinal Foods, Volunteer Healthca...
# 69                                          Data Analyst
# ...                                                  ...
# 12755                                Senior Data Analyst
# 12756                          Supply Chain Data Analyst
# 12759              Business Data Analyst - Data Products
# 12822                     Surgical Services Data Analyst
# 12877               Informatics/Clinical Data Analyst RN
#
#                         job_location  first_seen job_type
# 0                  Mountain View, CA  2023-12-20   Onsite
# 31               El Dorado Hills, CA  2023-12-20   Onsite
# 37               El Dorado Hills, CA  2023-12-20   Onsite
# ...

# %%
df1["job_location"].value_counts()
# Out:
# job_location
# United States     133
# New York, NY       63
# Atlanta, GA        48
# Chicago, IL        46
# Washington, DC     45
#                  ...
# Dundalk, MD         1
# Sykesville, MD      1
# Annapolis, MD       1
# Edgewood, MD        1
# Plant City, FL      1
# Name: count, Length: 590, dtype: int64
